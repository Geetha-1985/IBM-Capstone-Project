# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Scatter Plot**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will focus on creating and interpreting scatter plots to visualize relationships between variables and trends in the dataset. The provided dataset will be directly loaded into a pandas DataFrame, and various scatter plot-related visualizations will be created to explore developer trends, compensation, and preferences.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will:
#
# - Create and analyze scatter plots to examine relationships between variables.
#
# - Use scatter plots to identify trends and patterns in the dataset.
#
# - Focus on visualizations centered on scatter plots for better data-driven insights.

# %% [markdown]
# ## Setup: Working with the Database

# %% [markdown]
# **Install and import the required libraries**

# %%
# !pip install pandas
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 1: Load the dataset

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

df = pd.read_csv(file_path)
df.head(5)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Exploring Relationships with Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot for Age vs. Job Satisfaction

# %% [markdown]
# Visualize the relationship between respondents' age (`Age`) and job satisfaction (`JobSatPoints_6`). Use this plot to identify any patterns or trends.

# %%
import seaborn as sns

# %%
## Write your code here
df_touse = df.dropna(subset=['Age', 'JobSatPoints_6'])
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_touse, x='Age', y='JobSatPoints_6', hue='Age', palette='viridis')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# Explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`) using a scatter plot.

# %%
## Write your code here
df_touse = df.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6'])
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_touse, x='ConvertedCompYearly', y='JobSatPoints_6', hue='ConvertedCompYearly', palette='viridis')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Task 2: Enhancing Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot with Trend Line for Age vs. Job Satisfaction

# %% [markdown]
# Add a regression line to the scatter plot of Age vs. JobSatPoints_6 to highlight trends in the data.

# %%
## Write your code here
df_touse = df.dropna(subset=['Age', 'JobSatPoints_6'])

# Create a dictionary to map age ranges to numerical values
age_mapping = {
    'Under 18 years old': 0,
    '18-24 years old': 1,
    '25-34 years old': 2,
    '35-44 years old': 3,
    '45-54 years old': 4,
    '55-64 years old': 5,
    '65 years or older': 6,
    'Prefer not to say': 7
}

# Apply the mapping using apply
df_touse['AgeNum'] = df_touse['Age'].apply(lambda x: age_mapping.get(x, x))

plt.figure(figsize=(12, 8))
sns.regplot(x='AgeNum', y='JobSatPoints_6', data=df_touse, scatter_kws={'alpha':0.5}) 
#sns.scatterplot(data=df_touse, x='Age', y='JobSatPoints_6', hue='Age', palette='viridis')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_4252/2460314248.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_touse['AgeNum'] = df_touse['Age'].apply(lambda x: age_mapping.get(x, x))

# %% [markdown]
# #### 2. Scatter Plot for Age vs. Work Experience

# %% [markdown]
# Visualize the relationship between Age (`Age`) and Work Experience (`YearsCodePro`) using a scatter plot.

# %%
## Write your code here
## Write your code here
df_touse = df.dropna(subset=['Age', 'YearsCodePro'])
# Convert 'YearsCodePro' to numeric values, handling non-numeric entries
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_touse, x='Age', y='YearsCodePro', palette='viridis')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_4252/3837701242.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_touse, x='Age', y='YearsCodePro', palette='viridis')

# %% [markdown]
# ### Task 3: Combining Scatter Plots with Additional Features

# %% [markdown]
# #### 1. Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size

# %% [markdown]
# Create a bubble plot to explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), with bubble size representing age.

# %%
## Write your code here
df_touse = df.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6','Age'])
plt.figure(figsize=(12, 8))
#sns.scatterplot(data=df_touse, x='ConvertedCompYearly', y='JobSatPoints_6', hue='ConvertedCompYearly', palette='viridis')
bubble_plot = sns.scatterplot(data=df_touse, x='ConvertedCompYearly', y='JobSatPoints_6',
                              size='Age', sizes=(20, 200), alpha=0.5, hue='Age', palette='viridis')
plt.xticks(rotation=45)
plt.title('Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size')
plt.grid(True)
plt.legend(title='Age')
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Popular Programming Languages by Job Satisfaction

# %% [markdown]
# Visualize the popularity of programming languages (`LanguageHaveWorkedWith`) against job satisfaction using a scatter plot. Use points to represent satisfaction levels for each language.

# %%
## Write your code here
df_touse = df.dropna(subset=['LanguageHaveWorkedWith', 'JobSatPoints_6'])

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_touse, x='LanguageHaveWorkedWith', y='JobSatPoints_6', hue='LanguageHaveWorkedWith', palette='viridis')
plt.title('Scatter Plot of Popular Programming Languages by Job Satisfaction', fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Task 4: Scatter Plot Comparisons Across Groups

# %% [markdown]
# #### 1. Scatter Plot for Compensation vs. Job Satisfaction by Employment Type

# %% [markdown]
# Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), categorized by employment type (`Employment`). Use color coding or markers to differentiate between employment types.

# %%
## Write your code here
## Write your code here
df_touse = df.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6', 'Employment'])

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_touse, x='ConvertedCompYearly', y='JobSatPoints_6', hue='Employment', palette='viridis')
plt.title(' Scatter Plot for Compensation vs. Job Satisfaction by Employment Type', fontsize=16)
plt.xticks(rotation=45)
plt.legend(title='Employment Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Work Experience vs. Age Group by Country

# %% [markdown]
# Compare work experience (`YearsCodePro`) across different age groups (`Age`) and countries (`Country`). Use colors to represent different countries and markers for age groups.

# %%
## Write your code here
import seaborn as sns
df_touse = df.dropna(subset=['YearsCodePro', 'Age', 'Country'])

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_touse, x='Age', y='YearsCodePro', hue='Country', style='Age', palette='Set2', s=100)
plt.title('Scatter Plot of work experience across different age groups and countries ', fontsize=16)
plt.xticks(rotation=45)
plt.legend(title='Employment Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# With these scatter plots, you will have analyzed data relationships across multiple dimensions, including compensation, job satisfaction, employment types, and demographics, to uncover meaningful trends in the developer community.

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Analyze how numerical variables relate across specific groups, such as employment types and countries.
# - Use scatter plots effectively to represent multiple variables with color, size, and markers.
# - Gain insights into compensation, satisfaction, and demographic trends using advanced scatter plot techniques.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
